# %%
# 4-12 지하철 시간대별 데이터 시각화하기
# 하루 중 각 시간대 승차인원이 최고점에 다다른 역

import csv

f = open('subwaytime2008.csv', encoding='utf-8-sig')
data = csv.reader(f)

next(data)
next(data)

mxup = 0
mxup_t = 0

mxup_station = [[] for i in range(24)]   # 2차원 배열 https://hashcode.co.kr/questions/693/파이썬에서-2차원-배열은-어떻게-쓰나요

for row in data :
    for i in range(len(row)) :
        row[i] = row[i].replace(",","")   # 인원 수에서 쉼표 제거
    del row[-1]                           # 마지막열 작업 날짜 시간 제거
    row[4:] = map(int, row[4:])
    
    for i in range(24) :
        if row[i*2+4] > mxup :
            mxup = row[i*2+4]
            mxup_t = i
    mxup_station[mxup_t].append(row[3])
    mxup = 0
    mxup_t = 0

print('*** 하루 중 각 시간대 승차인원이 최고점에 다다른 역 ***')
for i in range(24) : 
    if len(mxup_station[i]) > 0 :
        print('')
    print((i+4)%24, '시 :', mxup_station[i])
# Out:
# *** 하루 중 각 시간대 승차인원이 최고점에 다다른 역 ***
# 4 시 : []
# 5 시 : []
# 6 시 : []
#
# ...

# %%
# 4-12 지하철 시간대별 데이터 시각화하기
# 하루 중 각 시간대 하차인원이 최고점에 다다른 역

import csv

f = open('subwaytime2008.csv', encoding='utf-8-sig')
data = csv.reader(f)

next(data)
next(data)

mxdn = 0
mxdn_t = 0

mxdn_station = [[] for i in range(24)]   # 2차원 배열 https://hashcode.co.kr/questions/693/파이썬에서-2차원-배열은-어떻게-쓰나요

for row in data :
    for i in range(len(row)) :
        row[i] = row[i].replace(",","")   # 인원 수에서 쉼표 제거
    del row[-1]                           # 마지막열 작업 날짜 시간 제거
    row[4:] = map(int, row[4:])
    
    for i in range(24) :
        if row[i*2+5] > mxdn :
            mxdn = row[i*2+5]
            mxdn_t = i
    if mxdn !=0 :        
        mxdn_station[mxdn_t].append(row[3])
    mxdn = 0
    mxdn_t = 0

print('*** 하루 중 각 시간대 하차인원이 최고점에 다다른 역 ***')
for i in range(24) : 
    if len(mxdn_station[i]) > 0 :
        print('')
    print((i+4)%24, '시 :', mxdn_station[i])
# Out:
# *** 하루 중 각 시간대 하차인원이 최고점에 다다른 역 ***
# 4 시 : []
# 5 시 : []
#
# 6 시 : ['대모산입구']
#
# 7 시 : ['일원', '지제', '동두천', '안산', '정왕', '구룡', '양원', '호구포', '김포공항', '둔촌오륜']
#
# ...
