# %%
import csv
import matplotlib.pyplot as plt

# 운영체제별 한글 폰트 설정
import os
os.name
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


f = open('dgpop202008.csv', encoding='utf-8-sig')
data = csv.reader(f)
result = []            # 빈 리스트 만들기

for row in data :
    if '성당동' in row[0] :           # 성당동이 포함된 행정구역 찾기
        for i in row[3:] :          # 0~100세 이상까지 모든 연령에 대해 반복
            result.append(int(i))   # 해당 연령 인구수 리스트에 순서대로 '정수'로 저장

plt.style.use(['dark_background'])
plt.figure(figsize = (10,5))
# plt.style.use('ggplot')
plt.title('2020.8. 달서구 성당동의 연령별 인구', color='y', size='15')
plt.bar(range(101), result)
plt.xticks(range(0,101,10))
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

# 운영체제별 한글 폰트 설정
import os
os.name
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


f = open('dgpop202008.csv', encoding='utf-8-sig')
data = csv.reader(f)
result = []            # 빈 리스트 만들기

for row in data :
    if '성당동' in row[0] :           # 성당동이 포함된 행정구역 찾기
        for i in row[3:] :          # 0~100세 이상까지 모든 연령에 대해 반복
            result.append(int(i))   # 해당 연령 인구수 리스트에 순서대로 '정수'로 저장

plt.style.use(['dark_background'])
plt.figure(figsize = (10,10))
# plt.style.use('ggplot')
plt.title('2020.8. 달서구 성당동의 연령별 인구', color='y', size='15')
plt.barh(range(101), result)
plt.yticks(range(0,101,10))
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

# 운영체제별 한글 폰트 설정
import os
os.name
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

f = open('gender202008.csv', encoding='utf-8-sig')
data = csv.reader(f)
m = []
f = []

for row in data :
    if '성당동' in row[0] :
        for i in range(0,101) :
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()

plt.style.use(['dark_background'])
plt.figure(figsize = (20,10), dpi = 300)
# plt.style.use('ggplot')
plt.title('2020.8. 달서구 성당동의 성별, 연령별 인구', color='g', size='20')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.xticks(range(-300,300,50))
plt.yticks(range(0,101,10))
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

# 운영체제별 한글 폰트 설정
import os
os.name
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

f = open('gender202008.csv', encoding='utf-8-sig')
data = csv.reader(f)
m = []
f = []
name = input('찾고 싶은 지역 이름은? : ')
for row in data :
    if name in row[0] :
        for i in range(0,101) :
            m.append(-int(row[i+3]))
            f.append(int(row[-(i+1)]))
f.reverse()

plt.style.use(['dark_background'])
plt.figure(figsize = (20,10), dpi = 300)
# plt.style.use('ggplot')
plt.title('2020.8. '+name+'의 성별 인구 분포', color='g', size='20')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.xticks(range(-300,300,50))
plt.yticks(range(0,101,10))
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역 이름은? : 대명3동
